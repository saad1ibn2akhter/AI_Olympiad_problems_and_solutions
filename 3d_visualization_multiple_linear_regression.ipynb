# %% [markdown]
# <a href="https://colab.research.google.com/github/saad1ibn2akhter/AI_Olympiad_problems_and_solutions/blob/main/3d_visualization_multiple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.linear_model import LinearRegression


# # Example dataset (2 features + 1 target)
# # Features: X1, X2 | Target: y
# X1 = np.random.rand(50) * 10
# X2 = np.random.rand(50) * 10
# y = 2.5 * X1 + 1.3 * X2 + 5 + np.random.randn(50) * 2  # Add noise

# # Combine features into a matrix
# X = np.column_stack((X1, X2))

# # Fit the model
# model = LinearRegression()
# model.fit(X, y)

# # Create a grid for plotting the plane
# x1_range = np.linspace(X1.min(), X1.max(), 20)
# x2_range = np.linspace(X2.min(), X2.max(), 20)
# X1_grid, X2_grid = np.meshgrid(x1_range, x2_range)

# # Predict values on the grid
# Y_pred = model.predict(np.column_stack((X1_grid.ravel(), X2_grid.ravel())))
# Y_pred = Y_pred.reshape(X1_grid.shape)

# # Plot
# fig = plt.figure(figsize=(10, 7))
# ax = fig.add_subplot(111, projection='3d')

# # Scatter plot of actual data
# ax.scatter(X1, X2, y, color='blue', label='Data points')

# # Regression plane
# ax.plot_surface(X1_grid, X2_grid, Y_pred, color='red', alpha=0.5)

# # Labels
# ax.set_xlabel('X1')
# ax.set_ylabel('X2')
# ax.set_zlabel('y')
# ax.set_title('Multiple Linear Regression Plane')
# ax.legend()

# plt.show()

# %%
X1 = np.random.rand(50)*10
X2 = np.random.rand(50)*10

y = 2.5*X1 + 1.5*X2 + np.random.rand(50)*2

X = np.column_stack((X1,X2))

model = LinearRegression()
model.fit(X,y)

x1_range = np.linspace(X1.min(),X1.max(),20)
x2_range = np.linspace(X2.min(),X2.max(),20)

X1_grid , X2_grid = np.meshgrid(x1_range,x2_range)

Y_pred = model.predict(np.column_stack((X1_grid.ravel() , X2_grid.ravel())))
Y_pred = Y_pred.reshape(X1_grid.shape)

fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111, projection ='3d')

ax.scatter(X1,X2,y,color='red', label ='data points')
ax.plot_surface(X1_grid, X2_grid , Y_pred, color='blue', alpha =0.5)
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('y')
ax.set_title('Multiple Linear Regression Plane')
ax.legend()

plt.show()

# %%
X1 = np.random.rand(50)*10
X2 = np.random.rand(50)*10
y = 2.6*X1 + 3.5*X2 + np.random.rand(50)*2

X = np.column_stack((X1,X2))

model  = LinearRegression()
model.fit(X,y)

x1_range = np.linspace(X1.min(),X1.max(),20)
x2_range = np.linspace(X2.min(),X2.max(),20)

X1_grid , X2_grid = np.meshgrid(x1_range, x2_range)

Y_pred = model.predict(np.column_stack((X1_grid.ravel() , X2_grid.ravel())))
Y_pred = Y_pred.reshape(X1_grid.shape)

fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(X1,X2,y,color='red', label='data points')
ax.plot_surface(X1_grid, X2_grid , Y_pred, color ='blue' ,alpha=0.2)#alpha kinda works like visibility / opacity
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('y')
ax.set_title('Multiple Linear Regression Plane')
ax.legend()

plt.show()
