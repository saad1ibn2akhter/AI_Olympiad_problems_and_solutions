# %% [markdown]
# <a href="https://colab.research.google.com/github/saad1ibn2akhter/AI_Olympiad_problems_and_solutions/blob/main/regex_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

# %%
chat1 = 'code: you ask too much questions :  1234567890 email: saad@gmail.io'
chat2 = 'code: shut up :  (123)-456-7890 ,email: saad@gmail.io'
pattern = '\d{10} | \(\d{3}\)-\d{3}-\d{4}'
# p2 = '\(\d{3}\)-\d{3}-\d{4}'
matches = re.findall(pattern,chat2)
print(matches)

email = '[a-zA-Z0-9]*@[a-zA-Z0-9]*.[a-zA-Z0-9]*'
m2 = re.findall(email,chat1)
print(m2)
# Out:
# [' (123)-456-7890']
# ['saad@gmail.io']
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-3211996378.py:3: SyntaxWarning: invalid escape sequence '\d'
#   pattern = '\d{10} | \(\d{3}\)-\d{3}-\d{4}'

# %%
#bit of scrappy work now
text ='''
Elon Reeve Musk is a businessman and entrepreneur known for his leadership of Tesla, SpaceX, Twitter, and xAI. Musk has been the wealthiest person in the world since 2021; as of October 2025, Forbes estimates his net worth to be around half a trillion $USD. Wikipedia
Born: 28 June 1971 (age 54 years), Pretoria, South Africa
Net worth: 497.4 billion USD (2025) Forbes
Children: Vivian Jenna Wilson, Nevada Alexander Musk, Saxon Musk, Kai Musk, Damian Musk, Griffin Musk
Spouse: Talulah Riley (m. 2013–2016), Talulah Riley (m. 2010–2012), Justine Musk (m. 2000–2008)
Organizations founded: Tesla · See more
Education: University of Pennsylvania School of Arts and Sciences (1997) · See more
'''

t2 = text.split(' ')
print(t2)
str = " ".join(t2)
print(str)
# Out:
# ['\nElon', 'Reeve', 'Musk', 'is', 'a', 'businessman', 'and', 'entrepreneur', 'known', 'for', 'his', 'leadership', 'of', 'Tesla,', 'SpaceX,', 'Twitter,', 'and', 'xAI.', 'Musk', 'has', 'been', 'the', 'wealthiest', 'person', 'in', 'the', 'world', 'since', '2021;', 'as', 'of', 'October', '2025,', 'Forbes', 'estimates', 'his', 'net', 'worth', 'to', 'be', 'around', 'half', 'a', 'trillion', '$USD.', 'Wikipedia\nBorn:', '28', 'June', '1971', '(age', '54', 'years),', 'Pretoria,', 'South', 'Africa\nNet', 'worth:', '497.4', 'billion', 'USD', '(2025)', 'Forbes\nChildren:', 'Vivian', 'Jenna', 'Wilson,', 'Nevada', 'Alexander', 'Musk,', 'Saxon', 'Musk,', 'Kai', 'Musk,', 'Damian', 'Musk,', 'Griffin', 'Musk\nSpouse:', 'Talulah', 'Riley', '(m.', '2013–2016),', 'Talulah', 'Riley', '(m.', '2010–2012),', 'Justine', 'Musk', '(m.', '2000–2008)\nOrganizations', 'founded:', 'Tesla', '·', 'See', 'more\nEducation:', 'University', 'of', 'Pennsylvania', 'School', 'of', 'Arts', 'and', 'Sciences', '(1997)', '·', '
# ...

# %%
age = 'age (\d+)'
dob = 'Born:\s*(\d{1,2})\s+([A-Za-z]+)\s+(\d{4})'
net_worth = 'Net worth:\s+(\d{1,5})'

children = 'Children:\s*(.*)'
spouses =  'Spouse:\s*(.*)'
org = 'Organizations founded:\s*(.*)'
edu = 'Education:\s*(.*)'
check = re.findall(children,str)
kiddo = check[0].split(',')


comm = [age,dob,net_worth,children,spouses,org,edu]

def match(pattern , text):
  yep = re.findall(pattern,text)
  if yep:
    return yep[0]


def get_info(text):
  a = re.findall(age,text)[0]
  b = re.findall(net_worth,text)[0]
  c = re.findall(children,text)
  d = re.findall(org,text)
  e = re.findall(edu,text)
  f = re.findall(dob,text)[0]

  return {
      'age ':a,
      'date ':f,
      'net worth ':b
  }

print(get_info(str))
# Out:
# {'age ': '54', 'date ': ('28', 'June', '1971'), 'net worth ': '497'}
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-1352808770.py:1: SyntaxWarning: invalid escape sequence '\d'
#   age = 'age (\d+)'
# /tmp/ipython-input-1352808770.py:2: SyntaxWarning: invalid escape sequence '\s'
# ...

# %%
text = '''
Follow our leader Elon musk on twitter here: https://twitter.com/elonmusk, more information
on Tesla's products can be found at https://www.tesla.com/. Also here are leading influencers
for tesla related news,
https://twitter.com/teslarati
https://twitter.com/dummy_tesla
https://twitter.com/dummy_2_tesla
'''
pattern = 'https://twitter\.com/([a-zA-Z0-9_]+)' # todo: type your regex here

X = re.findall(pattern, text)
print(X)
# Out:
# ['elonmusk', 'teslarati', 'dummy_tesla', 'dummy_2_tesla']
# <>:9: SyntaxWarning: invalid escape sequence '\.'
# <>:9: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipython-input-3329841223.py:9: SyntaxWarning: invalid escape sequence '\.'
#   pattern = 'https://twitter\.com/([a-zA-Z0-9_]+)' # todo: type your regex here

# %%
text = '''
Concentration of Risk: Credit Risk
Financial instruments that potentially subject us to a concentration of credit risk consist of cash, cash equivalents, marketable securities,
restricted cash, accounts receivable, convertible note hedges, and interest rate swaps. Our cash balances are primarily invested in money market funds
or on deposit at high credit quality financial institutions in the U.S. These deposits are typically in excess of insured limits. As of September 30, 2021
and December 31, 2020, no entity represented 10% or more of our total accounts receivable balance. The risk of concentration for our convertible note
hedges and interest rate swaps is mitigated by transacting with several highly-rated multinational banks.
Concentration of Risk: Supply Risk
We are dependent on our suppliers, including single source suppliers, and the inability of these suppliers to deliver necessary components of our
products in a timely manner at prices, quality levels and volumes acceptable to us, or our inability to efficiently manage these components from these
suppliers, could have a material adverse effect on our business, prospects, financial condition and operating results.
'''
pattern = 'Concentration of Risk: ([^\n]*)'

re.findall(pattern, text)
# Out:
# ['Credit Risk', 'Supply Risk']

# %%
text = '''
Tesla's gross cost of operating lease vehicles in FY2021 Q1 was $4.85 billion.
BMW's gross cost of operating vehicles in FY2021 S1 was $8 billion.
'''

pattern = 'FY(\d{4} (?:Q[1-4]|S[1-2]))'
matches = re.findall(pattern, text)
matches
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-364760362.py:6: SyntaxWarning: invalid escape sequence '\d'
#   pattern = 'FY(\d{4} (?:Q[1-4]|S[1-2]))'
# ['2021 Q1', '2021 S1']
