# %% [markdown]
# <a href="https://colab.research.google.com/github/saad1ibn2akhter/AI_Olympiad_problems_and_solutions/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier ,plot_tree
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('delivery.csv')
print(df.dtypes)
df.head(3)
# Out:
# id                     int64
# distance_km          float64
# package_weight_kg    float64
# traffic_level          int64
# on_time                int64
# dtype: object
#     id  distance_km  package_weight_kg  traffic_level  on_time
# 0   74       407.92               5.62              2        1
# 1   19       216.54              56.35              1        1
# 2  119       597.06             102.39             13        0

# %%
X = df.drop(columns=['id' , 'on_time'])
y = df['on_time']

X_train , X_test, y_train , y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
#do with decision tree (LOCAL first the Test Data)
dt = DecisionTreeClassifier(criterion='entropy' , max_depth=4)

dt.fit(X_train , y_train)

# yhat = dt.predict(X_test)
# acc = accuracy_score(y_test, yhat)

# print("accuracy : ",acc*100," %")

#-----------------------------------------------------------------------------------

test_df = pd.read_csv('delivery_test.csv')
test_df.head(1)

X = test_df.drop(columns=['id'])
print(X.columns)
print(X.dtypes)

# dt.fit(X, df['on_time'])
yhat_final = dt.predict(X)

# print(yhat_final[:2])
task1df= pd.DataFrame({
   'subtaskID':[1],
    'datapointID':[1],
    'answer':[round(test_df['traffic_level'].mean())]
})
task1df.to_csv('output.csv' ,index=False)

unique_vals = test_df['traffic_level'].unique()
print("Unique traffic_level values:", unique_vals)


if len(unique_vals) == 1:
    std_traffic_level = 0.0
else:
    std_traffic_level = round(np.std(test_df['traffic_level'], ddof=0), 2)

task2df = pd.DataFrame({
    'subtaskID': [2],
    'datapointID': [1],
    'answer': [std_traffic_level]
})

# std_traffic_level = round(np.std(test_df['traffic_level'], ddof=0), 2)
# task2df= pd.DataFrame({
#    'subtaskID':[2],
#     'datapointID':[1],
#     'answer':[std_traffic_level]
# })
task2df.to_csv('output.csv' ,mode='a', header=False, index=False)
task3df = pd.DataFrame({
    'subtaskID':[3]*len(test_df),
    'datapointID':test_df['id'],
    'answer':yhat_final
})

task3df.to_csv('output.csv' ,mode='a', header=False, index=False)
# Out:
# Index(['distance_km', 'package_weight_kg', 'traffic_level'], dtype='object')
# distance_km          float64
# package_weight_kg    float64
# traffic_level          int64
# dtype: object
# Unique traffic_level values: [ 2  6  9  7 10  3  1 13 14  8 11  5 12  4]
